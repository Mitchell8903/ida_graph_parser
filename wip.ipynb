# %% [markdown]
# # IDA CFG Analysis with ipysigma
#
# This notebook demonstrates how to extract, load, and visualize the Control Flow Graph (CFG) from an IDA database.

# %% [markdown]
# ### 1. Extract CFG from IDA Database
# This step requires `idapro` 9.0+ and a valid license.

# %%
import sys
import os
from src.extract_cfg import extract_cfg_from_db

# Replace with the path to your IDA database (.idb or .i64)
db_path = "/Users/mark/windows_share/test/reorder_and_pad.exe.i64"
json_path = "reorder_and_pad2.json"

if os.path.exists(db_path):
    json_path = extract_cfg_from_db(db_path, output_path=json_path)
else:
    print(f"Database {db_path} not found. Skipping extraction.")
# Out:
# Opening database: /Users/mark/windows_share/test/reorder_and_pad.exe.i64
# Number of functions found: 343
# Extracting imported functions...
# Found 77 imported functions.
# Extracting functions and intra-function edges...
# Skipping thunk function sub_140001040 @ 0x140001040
# Skipping thunk function sub_140001044 @ 0x140001044
# Skipping thunk function sub_14000104C @ 0x14000104c
# Skipping thunk function _guard_dispatch_icall_nop @ 0x140015300
# Skipping thunk function memset @ 0x140015308
# Skipping thunk function memmove @ 0x140015314
# Skipping thunk function memcmp @ 0x140015320
# Skipping thunk function memcpy @ 0x14001532c
# Skipping thunk function sub_140015AE8 @ 0x140015ae8
# Skipping thunk function __C_specific_handler @ 0x140015cfc
# Skipping thunk function __current_exception @ 0x140015d08
# Skipping thunk function __current_exception_context @ 0x140015d14
# Skipping thunk function _seh_filter_exe @ 0x140015d20
# Skipping thunk function _set_app_type @ 0x140015d2c
# Skipping thunk function __setusermatherr @ 0x140015d38
# Skipping thunk function _configure_narrow_argv @ 0x140015d44
# Skipping thunk function _initialize_narrow_environment @ 0x140015d50
# Skipping thunk function _get_initial_narrow_environment @ 0x140015d5c
# Skipping thunk function _initterm @ 0x140015d68
# Skipping thunk function _initterm_e @ 0x140015d74
# Skipping thunk function exit @ 0x140015d80
# Skipping thunk function _exit @ 0x140015d8c
# Skipping thunk function _set_fmode @ 0x140015d98
# Skipping thunk function __p___argc @ 0x140015da4
# Skipping thunk function __p___argv @ 0x140015db0
# Skipping thunk function _cexit @ 0x140015dbc
# Skipping thunk function _c_exit @ 0x140015dc8
# Skipping thunk function _register_thread_local_exe_atexit_callback @ 0x140015dd4
# Skipping thunk function _configthreadlocale @ 0x140015de0
# Skipping thunk function _set_new_mode @ 0x140015dec
# Skipping thunk function __p__commode @ 0x140015df8
# Skipping thunk function _initialize_onexit_table @ 0x140015e04
# Skipping thunk function _register_onexit_function @ 0x140015e10
# Skipping thunk function _crt_atexit @ 0x140015e1c
# Skipping thunk function terminate @ 0x140015e28
# Found 343 functions.
# Extracting inter-function calls...
# Found non-call link to main 5368713352 from sub_140001000 @ 0x140001000
# Extracting calls to imported functions...
# CFG exported to reorder_and_pad2.json

# %% [markdown]
# ### 2. Load and Visualize the Graph with ipysigma

# %%
from idadex import idaapi
from typing import Hashable
from networkx import k_core, DiGraph
import importlib
importlib.invalidate_caches()
from ipysigma import Sigma
import pandas as pd
import networkx as nx
import src.visualize_cfg as cfg
importlib.reload(cfg)
import os




def prune_graph(og: DiGraph[Hashable]) -> DiGraph[Hashable]:
    to_return = og.copy()
    print(f"Graph loaded: {len(to_return.nodes)} nodes, {len(to_return.edges)} edges")
    entrypoint = [x for x in to_return.nodes() if to_return.nodes[x]['entry_point'] == True]
    print(f"entrypoint is {entrypoint}")

    # remove self loops
    to_return.remove_edges_from(nx.selfloop_edges(to_return))

    to_return = collapse_thunks(to_return)
    to_return = cfg.collapse_chains(to_return)

    # remove nodes with degree <= 1
    to_return = k_core(to_return, 2)
    entrypoint = [x for x in to_return.nodes() if to_return.nodes[x]['entry_point'] == True]
    print(f"entrypoint is {entrypoint}")
    # to_be_removed = [x for  x in G.nodes() if G.degree()[x] <= 1]
    # print(f"Number of nodes to be removed: {len(to_be_removed)}")
    # G.remove_nodes_from(to_be_removed)
    # # Basic info
    # print(f"Number of functions after removing degree <= 1: {len(G.nodes)}")
    #
    # print(f"Number of nodes after collapsing chains: {len(G.nodes)}")
    # entrypoint = [x for x in G.nodes() if G.nodes[x]['entry_point'] == True]
    # if not entrypoint:
    #     print("No entrypoint found. Please check the graph.")
    #     raise ValueError("No entrypoint found")
    print(f"Graph pruned: {len(to_return.nodes)} nodes, {len(to_return.edges)} edges")
    return to_return

def collapse_thunks(G: nx.DiGraph):
    collapsed_G = G.copy()
    nodes_to_process = list(collapsed_G.nodes())

    for node in nodes_to_process:

        flags = collapsed_G.nodes[node].get('flags', {})
        if flags & idaapi.FUNC_THUNK:
            preds = list(collapsed_G.predecessors(node))
            succs = list(collapsed_G.successors(node))
            if len(succs) == 1:
                collapsed_G.remove_node(node)
                for pred in preds:
                    collapsed_G.add_edge(pred, succs[0])
    return collapsed_G

# Load the graph data
G = cfg.load_cfg(json_path)
if G is None:
    print(f"Could not load graph from {json_path}. Please make sure the file exists and it is a valid CFG JSON.")
    exit()

assert(G is not None)
pruned = prune_graph(G)

largest_degree = 0
def set_size(n, d) -> int:
    return len(d.get('instrs'))+G.out_degree(n)
# Out:
# Graph loaded: 5174 nodes, 8729 edges
# entrypoint is ['0x1400155d8']
# entrypoint is ['0x1400155d8']
# Graph pruned: 4881 nodes, 8345 edges

# %%
# Visualize with ipysigma
widget = Sigma(
    pruned,
    node_label='label',
    raw_node_color=lambda n, d: "red" if "main" in d.get("func") else d.get('color'),
    node_size=set_size,
    edge_color='type',
    label_font='sans-serif',
    default_edge_type='arrow',
    start_layout=10,
)
print(largest_degree)
display(widget)
# Out:
# 0
# Sigma(nx.DiGraph with 4,881 nodes and 8,345 edges)

# %% [markdown]
# Ways to reduce:
# - strongly connected components
# - remove nodes with degree <= 1
# - clique detection and collapse
# - graph community collapse
# min cuts
# - graph spectral?
# - laplacian?
# - adamic-adar index?

# %%
## needed to reload code changed on disk, this is the correct import
import src.summarize_graph as sg
importlib.reload(sg)
summaries = sg.summarize_graph(pruned, base_url="http://192.168.1.101:8000/v1", max_concurrent=256, model="qwen3-coder-next", cache_path="./cache.json")
# Out:
# Summarizing nodes:  45%|████▌     | 2219/4881 [01:43<3:44:51,  5.07s/node]
# remaining: {'0x1400070fc', '0x1400141c8', '0x1400016f8', '0x140005c64', '0x140014c28', '0x14000e1a4', '0x14000ec30', '0x14000775c', '0x140013f68', '0x14000bdc4', '0x14001240c', '0x140013874', '0x14000d518', '0x14000dd5c', '0x14000c61c', '0x14000877c', '0x140010b20', '0x140009a2c', '0x14000cac4', '0x14000b82c', '0x14000b0c4', '0x140011018', '0x14000defc', '0x140011160', '0x140016b2c', '0x140010f34', '0x1400067a8', '0x140009298', '0x140010414', '0x140016414', '0x140015f9c', '0x140015374', '0x140013da4', '0x14000e49c', '0x14000923c', '0x14000c7ec', '0x1400091c8', '0x140009bfc', '0x140010bc8', '0x14001386c', '0x14000a694', '0x1400032f4', '0x14000b0f4', '0x140013eec', '0x14000c018', '0x14000828c', '0x140008314', '0x14000e1f8', '0x140014af0', '0x14000fd1c', '0x140005ad0', '0x14000a860', '0x140011204', '0x140004ef0', '0x14000baac', '0x1400165c8', '0x1400162a8', '0x140007510', '0x14000e6c8', '0x140009674', '0x14000ad50', '0x140005cb4', '0x140016318', '0x14000fd14', '0x14000edc0', '0x140009b14', '0x14000e768', '0x14000a870', '0x1400127b4', '0x140008d64', '0x14000eed4', '0x14000f4d8', '0x140003240', '0x14000ca60', '0x140003c14', '0x140013f80', '0x140010348', '0x140003278', '0x14000681c', '0x140013ec0', '0x14000dea4', '0x14000d074', '0x140003d08', '0x140001b94', '0x14000b9c4', '0x140002f14', '0x14000fcf8', '0x14000f164', '0x14000afdc', '0x1400060f4', '0x1400097a0', '0x1400040b4', '0x140015460', '0x14001615c', '0x14000f78c', '0x140008514', '0x14000da18', '0x14000a2d0', '0x1400053a8', '0x140006050', '0x140010be4', '0x140009604', '0x14000cf4c', '0x14000e7f8', '0x14000d9d0', '0x14000c214', '0x14000b840', '0x14000a9c4', '0x1400166ac', '0x14000a208', '0x14000d470', '0x140009b90', '0x14000f2d0', '0x14000d9e